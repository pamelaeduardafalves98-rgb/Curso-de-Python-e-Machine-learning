# %% [markdown]
# # 🚀 Explorando o Python
#
# Este notebook mostra algumas possibilidades legais do que você pode fazer com Python.
#
# Execute cada célula e explore!

# %% [markdown]
# ## 👋 1. Primeiro programa

# %%
print("Olá, mundo! 👋")

# %% [markdown]
# ## 📦 2. Variáveis e entrada de dados

# %%
nome = input("Digite seu nome: ")
idade = int(input("Digite sua idade: "))
print(f"Olá {nome}, você tem {idade} anos!")

# %% [markdown]
# ## 🧮 3. Calculadora simples

# %%
a = float(input("Digite o primeiro número: "))
b = float(input("Digite o segundo número: "))
print("Soma:", a + b)
print("Multiplicação:", a * b)

# %% [markdown]
# ## 🔁 4. Repetição (loop)

# %%
for i in range(5):
    print("Número:", i)

# %% [markdown]
# ## 🤔 5. Condições

# %%
idade = int(input("Digite sua idade: "))
if idade >= 18:
    print("Maior de idade")
else:
    print("Menor de idade")

# %% [markdown]
# ## 🎲 6. Número aleatório

# %%
import random

numero = random.randint(1, 10)
print("Número sorteado:", numero)

# %% [markdown]
# ## 📋 7. Listas

# %%
frutas = ["maçã", "banana", "uva"]
for fruta in frutas:
    print(fruta)

# %% [markdown]
# ## 📊 8. Gráfico simples

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 15, 25]

plt.plot(x, y)
plt.title("Exemplo de gráfico")
plt.show()

# %% [markdown]
# ## ⚙️ 9. Automação simples

# %%
with open("arquivo.txt", "w") as f:
    f.write("Python é incrível!")

print("Arquivo criado!")

# %% [markdown]
# ## 🎮 10. Mini jogo (adivinhação)

# %%
import random

numero = random.randint(1, 5)
palpite = int(input("Adivinhe o número (1-5): "))

if palpite == numero:
    print("Acertou! 🎉")
else:
    print(f"Errou! O número era {numero}")
